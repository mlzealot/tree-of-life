# %%
import numpy as np
import pandas as pd

# %%
source_file_path, dest_file_path = "./src/data/Brain_v1.1.csv", "./src/data/BrainRegular.csv"
data = pd.read_csv(source_file_path)

# %%
current_colnames = list(data.columns)
new_colnames = list(data.iloc[9, :])
data = data.iloc[10:, :]
data.rename(columns = {curr: new_names for curr, new_names in zip(current_colnames, new_colnames)}, 
            inplace=True)
data.reset_index(inplace=True)
data.drop("index", axis=1, inplace=True)
# data.replace(np.nan, None, inplace=True)
display(data.head())

data.to_csv(dest_file_path)
# Out:
#     AS/1 AS/1/LABEL         AS/1/ID                        AS/2 AS/2/LABEL  \
# 0  brain      brain  UBERON:0000955  forebrain (prosencephalon)  forebrain
# 1  brain      brain  UBERON:0000955  forebrain (prosencephalon)  forebrain
# 2  brain      brain  UBERON:0000955  forebrain (prosencephalon)  forebrain
# 3  brain      brain  UBERON:0000955  forebrain (prosencephalon)  forebrain
# 4  brain      brain  UBERON:0000955  forebrain (prosencephalon)  forebrain
#
#           AS/2/ID                      AS/3                AS/3/LABEL  \
# 0  UBERON:0001890  gray matter of forebrain  gray matter of forebrain
# 1  UBERON:0001890  gray matter of forebrain  gray matter of forebrain
# 2  UBERON:0001890  gray matter of forebrain  gray matter of forebrain
# 3  UBERON:0001890  gray matter of forebrain  gray matter of forebrain
# 4  UBERON:0001890  gray matter of forebrain  gray matter of forebrain
#
#           AS/3/ID             AS/4  ... BGene/6/ID FTU/1 FTU/1/LABEL FTU/1/ID  \
# 0  UBERON:0019264  cerebral cortex  ...        NaN   NaN         NaN      NaN
# 1  UBERON:0019264  cerebral cortex  ...        NaN   NaN         NaN      NaN
# 2  UBERON:0019264  cerebral cortex  ...        NaN   NaN         NaN      NaN
# 3  UBERON:0019264  cerebral cortex  ...        NaN   NaN         NaN      NaN
# 4  UBERON:0019264  cerebral cortex  ...        NaN   NaN         NaN      NaN
#
#   REF/1 REF/1/DOI REF/1/NOTES REF/2 REF/2/DOI REF/2/NOTES
# 0   NaN       NaN         NaN   NaN       NaN         NaN
# 1   NaN       NaN         NaN   NaN       NaN         NaN
# 2   NaN       NaN         NaN   NaN       NaN         NaN
# 3   NaN       NaN         NaN   NaN       NaN         NaN
# 4   NaN       NaN         NaN   NaN       NaN         NaN
#
# [5 rows x 59 columns]
