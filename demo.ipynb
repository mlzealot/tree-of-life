# %%
import numpy as np
import pandas as pd

# %%
source_file_path, dest_file_path = "./src/data/Kidney_v1.1.csv", "./src/data/KidneyRegular.csv"
data = pd.read_csv(source_file_path)

# %%
current_colnames = list(data.columns)

new_colnames = list(data.iloc[9, :])
data = data.iloc[10:, :]
data.rename(columns = {curr: new_names for curr, new_names in zip(current_colnames, new_colnames)}, 
            inplace=True)
data.reset_index(inplace=True)
data.drop("index", axis=1, inplace=True)
# data.replace(np.nan, None, inplace=True)
display(data.head())
# Out:
#      AS/1 AS/1/LABEL         AS/1/ID              AS/2        AS/2/LABEL  \
# 0  kidney     kidney  UBERON:0002113    kidney capsule    kidney capsule
# 1  kidney     kidney  UBERON:0002113  cortex of kidney  cortex of kidney
# 2  kidney     kidney  UBERON:0002113  cortex of kidney  cortex of kidney
# 3  kidney     kidney  UBERON:0002113  cortex of kidney  cortex of kidney
# 4  kidney     kidney  UBERON:0002113     renal medulla     renal medulla
#
#           AS/2/ID                               AS/3  \
# 0  UBERON:0002015                                NaN
# 1  UBERON:0001225             outer cortex of kidney
# 2  UBERON:0001225              juxtamedullary cortex
# 3  UBERON:0001225                      medullary ray
# 4  UBERON:0000362  kidney outer medulla outer stripe
#
#                           AS/3/LABEL         AS/3/ID AS/4  ... REF/3/NOTES  \
# 0                                NaN             NaN  NaN  ...         NaN
# ...

# %%
temp = list(data.loc[data["CT/1/ID"].isna() & (~(data["CT/1/LABEL"].isna())), "CT/1/LABEL"])
print(temp)
data.loc[data["CT/1/ID"].isna() & (~(data["CT/1/LABEL"].isna())), "CT/1/ID"] = temp
# Out:
# ['PT-S3', 'DTL1', 'DTL2', 'DTL3', 'DCT1', 'DCT2', 'CNT-PC', 'CNT-IC', 'CNT-IC-A', 'CNT-IC-B', 'tPC-IC', 'CD-IC-A']

# %%
def replaceNans(col_1, col_2):
    print("Col1, col2", str(col_1), str(col_2))
    if(str(col_1) == "nan" and (str(col_2) != "nan")):
        print(col_2)
    return str(col_2)

# %%
data["CT/1/ID"] = data.apply(lambda x: replaceNans(x["CT/1/ID"], x["CT/1/LABEL"]), axis=1)
# Out:
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 CL:1000452 parietal epithelial cell
# Col1, col2 CL:0000653 glomerular visceral epithelial cell
# Col1, col2 CL:1001005 glomerular capillary endothelial cell
# Col1, col2 CL:1000742 glomerular mesangial cell
# Col1, col2 CL:0002306 epithelial cell of proximal tubule
# Col1, col2 nan nan
# Col1, col2 nan nan
# Col1, col2 PT-S3 PT-S3
# Col1, col2 CL:1001111 kidney loop of Henle thin descending limb epithelial cell
# Col1, col2 DTL1 DTL1
# Col1, col2 DTL2 DTL2
# Col1, col2 DTL3 DTL3
# Col1, col2 CL:1001107 kidney loop of Henle thin ascending limb epithelial cell
# Col1, col2 CL:1001106 kidney loop of Henle thick ascending limb epithelial cell
# ...

# %%
data[["CT/1/ID", "CT/1/LABEL", "CT/1"]]
# Out:
#              CT/1/ID        CT/1/LABEL                              CT/1
# 0                nan               NaN  capsule mesenchymal stromal cell
# 1                nan               NaN                               NaN
# 2                nan               NaN                               NaN
# 3                nan               NaN                               NaN
# 4                nan               NaN                               NaN
# ..               ...               ...                               ...
# 72  cytotoxic T cell  cytotoxic T cell                  Cytotoxic T Cell
# 73            B cell            B cell                            B cell
# 74       plasma cell       plasma cell                       Plasma cell
# 75        neutrophil        neutrophil                        Neutrophil
# 76         mast cell         mast cell                         Mast cell
#
# [77 rows x 3 columns]

# %%
data_no_ct_ids = data[data["CT/1/ID"].isna() & (~(data["CT/1/LABEL"].isna()))]
values_to_assign = list(data_no_ct_ids["CT/1/LABEL"])
data_no_ct_ids[["CT/1/ID", "CT/1/LABEL", "CT/1"]]
# Out:
# Empty DataFrame
# Columns: [CT/1/ID, CT/1/LABEL, CT/1]
# Index: []

# %%
data[["CT/1/ID", "CT/1/LABEL", "CT/1"]]
# Out:
#        CT/1/ID        CT/1/LABEL                              CT/1
# 0          NaN               NaN  capsule mesenchymal stromal cell
# 1          NaN               NaN                               NaN
# 2          NaN               NaN                               NaN
# 3          NaN               NaN                               NaN
# 4          NaN               NaN                               NaN
# ..         ...               ...                               ...
# 72  CL:0000910  cytotoxic T cell                  Cytotoxic T Cell
# 73  CL:0000236            B cell                            B cell
# 74  CL:0000786       plasma cell                       Plasma cell
# 75  CL:0000775        neutrophil                        Neutrophil
# 76  CL:0000097         mast cell                         Mast cell
#
# [77 rows x 3 columns]

# %%
data.to_csv(dest_file_path)
